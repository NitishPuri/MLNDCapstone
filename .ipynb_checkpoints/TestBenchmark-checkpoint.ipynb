# %%
import time

import numpy as np
import pandas as pd
from scipy import ndimage
from tqdm import tqdm

from matplotlib import pyplot as plt
import seaborn as sns
import cv2

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %config IPCompleter.greedy=True

# %%
from utils.params import *
from utils.filename import *
from utils.image import *
import utils.models as models
from utils.read_activations import *

# dir(models)
# Out:
# Using TensorFlow backend.

# %%
train_masks = pd.read_csv(TRAIN_MASKS_CSV_PATH)
    
metadata = pd.read_csv(METADATA_CSV_PATH)
    
train_masks.head()
# Out:
#                    img                                           rle_mask
# 0  00087a6bd4dc_01.jpg  879386 40 881253 141 883140 205 885009 17 8850...
# 1  00087a6bd4dc_02.jpg  873779 4 875695 7 877612 9 879528 12 881267 15...
# 2  00087a6bd4dc_03.jpg  864300 9 866217 13 868134 15 870051 16 871969 ...
# 3  00087a6bd4dc_04.jpg  879735 20 881650 26 883315 92 883564 30 885208...
# 4  00087a6bd4dc_05.jpg  883365 74 883638 28 885262 119 885550 34 88716...

# %%
import imp
imp.reload(models)
man_model = models.get_manufacturer_model()

# %%
man_model.load_weights('models/manufacturer_model.best_weights.hdf5')

# %%
import imp
imp.reload(models)
# imp.reload(losses)
baseline_model = models.get_baseline_model()
baseline_model.summary()
# Out:
# <module 'utils.models' from 'D:\\tree\\UdacityMachineLearning\\MLNDCapstone\\utils\\models.py'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      448
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 1)       801
# =================================================================
# Total params: 5,889
# Trainable params: 5,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_model.load_weights('models/baseline_model.best_weights.hdf5')

# %%
sample_car_code = '00087a6bd4dc'
sample_angle_code = '04'

# %%
from utils.image import *
imp.reload(utils.image)
imp.reload(utils.filename)
# Out:
# <module 'utils.image' from 'D:\\tree\\UdacityMachineLearning\\MLNDCapstone\\utils\\image.py'>
# <module 'utils.filename' from 'D:\\tree\\UdacityMachineLearning\\MLNDCapstone\\utils\\filename.py'>

# %%
sample = read_image(sample_car_code, sample_angle_code)

fig, ax = plt.subplots(1, 3, figsize=(16, 16))
# ax = ax.ravel()

sample = resize(sample)
x_batch = []
x_batch.append(sample)
x_batch = np.array(x_batch, np.float32) /255
sample_pred = baseline_model.predict(x_batch).squeeze()

sample.__class__
ax[0].imshow(sample)
ax[1].imshow(sample_pred, cmap='gray')
ax[2].imshow(sample_pred > 0.01, cmap='gray')
# plt.imshow(sample_pred > .5, cmap = 'gray')
# Out:
# numpy.ndarray

# %%
np.max(sample_pred)
plt.imshow(sample_pred > .01, cmap = 'gray')
# Out:
# 0.037414499

# %%
from utils.vis import *
imp.reload(utils.vis)

vis_baseline_predictions(baseline_model)
# Out:
# <module 'utils.vis' from 'D:\\tree\\UdacityMachineLearning\\MLNDCapstone\\utils\\vis.py'>

# %%
imp.reload(utils.image)
import inspect

# dir(read_image)
inspect.signature(read_image)
# read_image.__dict__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-21c97c60c7aa> in <module>()
# ----> 1 imp.reload(utils.image)
#       2 import inspect
#       3
#       4 # dir(read_image)
#       5 inspect.signature(read_image)
#
# NameError: name 'imp' is not defined

# %%
# imp.reload(utils.params)
# imp.reload(utils.data)
# imp.reload(utils.image)
# imp.reload(utils.filename)

import utils.data as data
import utils.encoder as encoder

threshold = 0.001

orig_width = 1918
orig_height = 1280

rles = []
ids_test = data.list_test_files()
print('Predicting on {} samples with batch_size = {}...'.format(len(ids_test), BATCH_SIZE))
for start in tqdm(range(0, len(ids_test), BATCH_SIZE)):
    x_batch = []
    end = min(start + BATCH_SIZE, len(ids_test))
    ids_test_batch = ids_test[start:end]
    for id in ids_test_batch:
        car_code, angle_code = filename_to_code(id)
        img = read_image(car_code, angle_code, test = True)
        img = resize(img)
        x_batch.append(img)
    x_batch = np.array(x_batch, np.float32) / 255
    preds = baseline_model.predict_on_batch(x_batch)
    preds = np.squeeze(preds, axis = 3)
    for pred in preds:
        prob = cv2.resize(pred, (orig_width, orig_height))
        mask = prob > threshold
        rle = encoder.run_length_encode(mask)
        rles.append(rle)

print("Generating submission file,..")
df = pd.DataFrame({'img':ids_test, 'rle_mask':rles})
df.to_csv('submit/baseline_{}.csv.gz'.format(threshold), index = False, compression='gzip')
# Out:
# Predicting on 100064 samples with batch_size = 16...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 6254/6254 [1:39:57<00:00,  1.01it/s]
# Generating submission file,..
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-118db628d266> in <module>()
#      34
#      35 print("Generating submission file,..")
# ---> 36 df = pd.DataFrame({'img':names, 'rle_mask':rles})
#      37 df.to_csv('submit/baseline_{}.csv.gz'.format(threshold), index = False, compression='gzip')
#
# NameError: name 'names' is not defined

# %%
print("Generating submission file,..")
df = pd.DataFrame({'img':ids_test, 'rle_mask':rles})
df.to_csv('subm/baseline_{}.csv.gz'.format(threshold), index = False, compression='gzip')
print("File created,..")
# Out:
# Generating submission file,..

# %%
from skimage import measure, morphology
limg = measure.label(mask)
props = measure.regionprops(limg)
props = sorted(props, key=lambda p: -p.area)
# Erase all except the biggest blob
mask &= (limg == props[0].label)

# %%
import numpy as np
sample = read_image(sample_car_code, sample_angle_code)
sample = resize(sample)
x_batch = []
x_batch.append(sample)
x_batch = np.array(x_batch, np.float32) /255

# %%
activations = get_activations(baseline_model, x_batch, print_shape_only = True)
# Out:
# ----- activations -----
# (1, 128, 128, 16)
# (1, 128, 128, 32)
# (1, 128, 128, 1)

# %%
for i, activation_map in enumerate(activations):
    print('Displaying activation map {}'.format(i))
    shape = activation_map.shape
    activation_map = activation_map[0]
    num_filters = shape[3]
    print("num_filters : ", num_filters)
    fig_size = int(np.ceil(np.sqrt(num_filters)))
    print("fig_size : " , fig_size)
    if(num_filters == 1):
        img = activation_map[:,:,0]
#         img = visualize_activation(model, layer_idx, filter_indices = 0)        
        fig, ax = plt.subplots(1, 1, figsize=(20, 20))
        ax.imshow(img)
    else:        
        fig, ax = plt.subplots(fig_size, fig_size, figsize=(20, 20))
        for i in range(num_filters):
            img = activation_map[:,:,i]
    #         img = visualize_activation(model, layer_idx, filter_indices = i)
            ax[int(i/fig_size), (i%fig_size)].imshow(img)
# Out:
# Displaying activation map 0
# (1, 128, 128, 16)
# (128, 128, 16)
# num_filters :  16
# fig_size :  4
# Displaying activation map 1
# (1, 128, 128, 32)
# (128, 128, 32)
# num_filters :  32
# fig_size :  6
# Displaying activation map 2
# (1, 128, 128, 1)
# (128, 128, 1)
# num_filters :  1
# fig_size :  1

# %%
display_activations(activations)
# Out:
# Displaying activation map 0
# Displaying activation map 1
# Displaying activation map 2

# %%
layers = baseline_model.layers

# %%
for layer in layers:
    print (layer.name)
# Out:
# conv2d_4
# conv2d_5
# conv2d_6

# %%
from vis.utils import utils

# %%
layer_idx = utils.find_layer_idx(baseline_model, 'conv2d_6')
layer_idx
# Out:
# 2

# %%
from keras import activations
#swap softmax with linear
baseline_model.layers[2].activation = activations.linear
baseline_model = utils.apply_modifications(baseline_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ca14e42de5e3> in <module>()
#       2 #swap softmax with linear
#       3 baseline_model.layers[2].activation = activations.linear
# ----> 4 baseline_model = utils.apply_modifications(baseline_model)
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\vis\utils\utils.py in apply_modifications(model)
#     122     try:
#     123         model.save(model_path)
# --> 124         return load_model(model_path)
#     125     finally:
#     126         os.remove(model_path)
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\models.py in load_model(filepath, custom_objects, compile)
#     262                       metrics=metrics,
#     263                       loss_weights=loss_weights,
# --> 264                       sample_weight_mode=sample_weight_mode)
#     265
#     266         # Set optimizer weights.
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\models.py in compile(self, optimizer, loss, metrics, sample_weight_mode, **kwargs)
#     779                            metrics=metrics,
#     780                            sample_weight_mode=sample_weight_mode,
# --> 781                            **kwargs)
#     782         self.optimizer = self.model.optimizer
#     783         self.loss = self.model.loss
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, **kwargs)
#     679             loss_functions = [losses.get(l) for l in loss]
#     680         else:
# --> 681             loss_function = losses.get(loss)
#     682             loss_functions = [loss_function for _ in range(len(self.outputs))]
#     683         self.loss_functions = loss_functions
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\losses.py in get(identifier)
#     100     if isinstance(identifier, six.string_types):
#     101         identifier = str(identifier)
# --> 102         return deserialize(identifier)
#     103     elif callable(identifier):
#     104         return identifier
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\losses.py in deserialize(name, custom_objects)
#      92                                     module_objects=globals(),
#      93                                     custom_objects=custom_objects,
# ---> 94                                     printable_module_name='loss function')
#      95
#      96
#
# D:\Installations\Anaconda\envs\tensorflow\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     157             if fn is None:
#     158                 raise ValueError('Unknown ' + printable_module_name +
# --> 159                                  ':' + function_name)
#     160         return fn
#     161     else:
#
# ValueError: Unknown loss function:bce_dice_loss

# %%
import utils.vis as visutils
import imp
imp.reload(visutils)

layer_idx = 2
visutils.vis_activation_maximizations(baseline_model, layer_idx)
# Out:
# <module 'utils.vis' from 'D:\\tree\\UdacityMachineLearning\\MLNDCapstone\\utils\\vis.py'>
# num_filters :  1
# fig_size :  1

# %%
plt.imshow('/input/car_and_dog/notcar_04.jpg')
